# %%
data_path = "repositories.json"

# %%
import pandas as pd
import plotly.express as px

df = pd.read_json(data_path)

# %%
import matplotlib.pyplot as plt

x = []
y = []
z = []


for row in df.itertuples():
	x.append(row.LanguageCode)
	y.append(row.StargazersCount)
		

plt.bar(x, y, color = 'g', width = 0.72, label = "Stars")
plt.xlabel('Language')
plt.ylabel('Star Count')
plt.title('StarCount of Repos')
plt.legend()
plt.show()

# %%
df.head()
# Out:
#   LanguageCode                                                Url  \
# 0           C#   https://api.github.com/repos/microsoft/PowerToys
# 1           C#  https://api.github.com/repos/shadowsocks/shado...
# 2           C#          https://api.github.com/repos/2dust/v2rayN
# 3           C#     https://api.github.com/repos/dotnet/aspnetcore
# 4           C#    https://api.github.com/repos/CodeHubApp/CodeHub
#
#                                              HtmlUrl  \
# 0             https://github.com/microsoft/PowerToys
# 1  https://github.com/shadowsocks/shadowsocks-win...
# 2                    https://github.com/2dust/v2rayN
# 3               https://github.com/dotnet/aspnetcore
# 4              https://github.com/CodeHubApp/CodeHub
#
#                                             CloneUrl  \
# 0         https://github.com/microsoft/PowerToys.git
# 1  https://github.com/shadowsocks/shadowsocks-win...
# 2                https://github.com/2dust/v2rayN.git
# 3           https://github.com/dotnet/aspnetcore.git
# 4          https://github.com/CodeHubApp/CodeHub.git
#
#                                               GitUrl  \
# 0           git://github.com/microsoft/PowerToys.git
# 1  git://github.com/shadowsocks/shadowsocks-windo...
# 2                  git://github.com/2dust/v2rayN.git
# 3             git://github.com/dotnet/aspnetcore.git
# 4            git://github.com/CodeHubApp/CodeHub.git
#
#                                               SshUrl  \
# 0             git@github.com:microsoft/PowerToys.git
# 1  git@github.com:shadowsocks/shadowsocks-windows...
# 2                    git@github.com:2dust/v2rayN.git
# 3               git@github.com:dotnet/aspnetcore.git
# 4              git@github.com:CodeHubApp/CodeHub.git
#
#                                               SvnUrl MirrorUrl         Id  \
# 0             https://github.com/microsoft/PowerToys      None  184456251
# 1  https://github.com/shadowsocks/shadowsocks-win...      None    7600409
# 2                    https://github.com/2dust/v2rayN      None  199570071
# 3               https://github.com/dotnet/aspnetcore      None   17620347
# 4              https://github.com/CodeHubApp/CodeHub      None   11620669
#
#                              NodeId  ... AllowSquashMerge AllowMergeCommit  \
# 0  MDEwOlJlcG9zaXRvcnkxODQ0NTYyNTE=  ...              NaN              NaN
# 1      MDEwOlJlcG9zaXRvcnk3NjAwNDA5  ...              NaN              NaN
# 2  MDEwOlJlcG9zaXRvcnkxOTk1NzAwNzE=  ...              NaN              NaN
# 3  MDEwOlJlcG9zaXRvcnkxNzYyMDM0Nw==  ...              NaN              NaN
# 4  MDEwOlJlcG9zaXRvcnkxMTYyMDY2OQ==  ...              NaN              NaN
#
#   HasPages  SubscribersCount    Size Archived  \
# 0    False                 0  296342    False
# 1    False                 0   13485    False
# 2    False                 0   13407    False
# 3    False                 0  325559    False
# 4     True                 0   75636     True
#
#                                               Topics  DeleteBranchOnMerge  \
# 0  [color-picker, desktop, fancyzones, keyboard-m...                  NaN
# 1                      [c-sharp, proxy, shadowsocks]                  NaN
# 2  [proxy, shadowsocks, socks5, trojan, v2fly, v2...                  NaN
# 3                [aspnetcore, dotnet, hacktoberfest]                  NaN
# 4             [c-sharp, codehub, github, reactiveui]                  NaN
#
#    Visibility  AllowAutoMerge
# 0           0             NaN
# 1           0             NaN
# 2           0             NaN
# 3           0             NaN
# 4           0             NaN
#
# [5 rows x 45 columns]

# %%
fig = px.bar(df, x="LanguageCode", y="StargazersCount", color="LanguageCode", barmode="group")
fig.show()

# %%
fig = px.line(df, x = 'LanguageCode', y = 'StargazersCount', title='')
fig.show()

# %%
fig = px.scatter(df, x = 'LanguageCode', y = 'StargazersCount', color = 'LanguageCode', title='')
fig.show()

# %%
fig = px.scatter_3d(df, x = 'OpenIssuesCount', y = 'StargazersCount', z = 'ForksCount', color = 'LanguageCode', title='')
fig.show()

# %%
fig = px.bar_polar(df, r = 'StargazersCount', theta = 'LanguageCode', color = 'LanguageCode', title='')
fig.show()

# %%
fig = px.line_polar(df, r = 'StargazersCount', theta = 'LanguageCode', color = 'LanguageCode', line_close = True, title='')
fig.show()
# Out:
# c:\Users\salih\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\salih\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\salih\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\salih\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\salih\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\salih\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\salih\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\salih\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\salih\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\salih\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\salih\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
fig = px.scatter_polar(df, r = 'StargazersCount', theta = 'LanguageCode', color = 'LanguageCode', title='')
fig.show()

# %%
fig = px.scatter_3d(df, x = 'OpenIssuesCount', y = 'StargazersCount', z = 'ForksCount', color = 'LanguageCode', title='')
fig.show()

# %%
df.hist(column = 'StargazersCount', by = 'LanguageCode', bins = 50, figsize = (10, 10))
# Out:
# array([[<AxesSubplot: title={'center': 'C'}>,
#         <AxesSubplot: title={'center': 'C#'}>,
#         <AxesSubplot: title={'center': 'C++'}>],
#        [<AxesSubplot: title={'center': 'Go'}>,
#         <AxesSubplot: title={'center': 'Java'}>,
#         <AxesSubplot: title={'center': 'Js'}>],
#        [<AxesSubplot: title={'center': 'PHP'}>,
#         <AxesSubplot: title={'center': 'Python'}>,
#         <AxesSubplot: title={'center': 'Ruby'}>],
#        [<AxesSubplot: title={'center': 'Swift'}>,
#         <AxesSubplot: title={'center': 'Ts'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
df.mean()
# Out:
# C:\Users\salih\AppData\Local\Temp\ipykernel_31668\3698961737.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
# Id                     5.827643e+07
# IsTemplate             4.545455e-03
# Private                0.000000e+00
# Fork                   0.000000e+00
# ForksCount             3.063225e+03
# StargazersCount        1.677474e+04
# WatchersCount          1.677474e+04
# OpenIssuesCount        3.869009e+02
# Parent                          NaN
# Source                          NaN
# HasIssues              9.427273e-01
# HasWiki                6.290909e-01
# HasDownloads           9.736364e-01
# AllowRebaseMerge                NaN
# AllowSquashMerge                NaN
# AllowMergeCommit                NaN
# HasPages               2.481818e-01
# SubscribersCount       0.000000e+00
# Size                   1.268221e+05
# Archived               3.727273e-02
# DeleteBranchOnMerge             NaN
# Visibility             0.000000e+00
# AllowAutoMerge                  NaN
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\salih\AppData\Local\Temp\ipykernel_31668\530051474.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
# Id                     29946937.5
# IsTemplate                    0.0
# Private                       0.0
# Fork                          0.0
# ForksCount                 1730.0
# StargazersCount           11512.0
# WatchersCount             11512.0
# OpenIssuesCount             104.0
# Parent                        NaN
# Source                        NaN
# HasIssues                     1.0
# HasWiki                       1.0
# HasDownloads                  1.0
# AllowRebaseMerge              NaN
# AllowSquashMerge              NaN
# AllowMergeCommit              NaN
# HasPages                      0.0
# SubscribersCount              0.0
# Size                      20147.5
# Archived                      0.0
# DeleteBranchOnMerge           NaN
# Visibility                    0.0
# AllowAutoMerge                NaN
# dtype: float64

# %%
df['StargazersCount'].max() - df['StargazersCount'].min()
# Out:
# 355080

# %%
df['ForksCount'].max() - df['ForksCount'].min()
# Out:
# 87305

# %%
df.std()
# Out:
# C:\Users\salih\AppData\Local\Temp\ipykernel_31668\3390915376.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
# Id                     7.445124e+07
# IsTemplate             6.729718e-02
# Private                0.000000e+00
# Fork                   0.000000e+00
# ForksCount             5.262888e+03
# StargazersCount        2.070724e+04
# WatchersCount          2.070724e+04
# OpenIssuesCount        9.940366e+02
# Parent                          NaN
# Source                          NaN
# HasIssues              2.324687e-01
# HasWiki                4.832679e-01
# HasDownloads           1.602871e-01
# AllowRebaseMerge                NaN
# AllowSquashMerge                NaN
# AllowMergeCommit                NaN
# HasPages               4.321544e-01
# SubscribersCount       0.000000e+00
# Size                   3.611832e+05
# Archived               1.895155e-01
# DeleteBranchOnMerge             NaN
# Visibility             0.000000e+00
# AllowAutoMerge                  NaN
# dtype: float64

# %%
df.var()
# Out:
# C:\Users\salih\AppData\Local\Temp\ipykernel_31668\1568254755.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
# Id                     5.542987e+15
# IsTemplate             4.528911e-03
# Private                0.000000e+00
# Fork                   0.000000e+00
# ForksCount             2.769799e+07
# StargazersCount        4.287897e+08
# WatchersCount          4.287897e+08
# OpenIssuesCount        9.881088e+05
# Parent                          NaN
# Source                          NaN
# HasIssues              5.404169e-02
# HasWiki                2.335479e-01
# HasDownloads           2.569195e-02
# AllowRebaseMerge                NaN
# AllowSquashMerge                NaN
# AllowMergeCommit                NaN
# HasPages               1.867574e-01
# SubscribersCount       0.000000e+00
# Size                   1.304533e+11
# Archived               3.591612e-02
# DeleteBranchOnMerge             NaN
# Visibility             0.000000e+00
# AllowAutoMerge                  NaN
# dtype: float64
